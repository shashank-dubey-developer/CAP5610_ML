# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import SequentialFeatureSelector
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Reading csv files of Testing and Training Data

# %%
train_dataframe = pd.read_csv('./Data/train.csv', index_col='PassengerId')
test_dataframe = pd.read_csv('./Data/test.csv', index_col='PassengerId')

# Dimensions and Preview
print('train_dataframe dimensions', train_dataframe.shape)
print('test_dataframe dimensions', test_dataframe.shape)
train_dataframe.head(10).style.background_gradient(cmap="Spectral")
# Out:
# train_dataframe dimensions (8693, 13)
# test_dataframe dimensions (4277, 12)
# <style type="text/css">
# #T_32988_row0_col4 {
#   background-color: #eef8a4;
#   color: #000000;
# }
# #T_32988_row0_col6, #T_32988_row0_col7, #T_32988_row0_col8, #T_32988_row0_col9, #T_32988_row0_col10, #T_32988_row1_col7, #T_32988_row2_col8, #T_32988_row3_col6, #T_32988_row5_col6, #T_32988_row5_col8, #T_32988_row5_col10, #T_32988_row6_col9, #T_32988_row6_col10, #T_32988_row7_col6, #T_32988_row7_col7, #T_32988_row7_col8, #T_32988_row7_col9, #T_32988_row8_col6, #T_32988_row8_col10, #T_32988_row9_col4, #T_32988_row9_col6, #T_32988_row9_col7, #T_32988_row9_col8, #T_32988_row9_col9, #T_32988_row9_col10 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_32988_row1_col4, #T_32988_row1_col10 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_32988_row1_col6 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_32988_row1_col8 {
#   background-color: #c32a4b;
#   color: #f1f1f1;
# }
# #T_32988_row1_col9 {
#   background-color: #c9314c;
#   color: #f1f1f1;
# }
# #T_32988_row2_col4, #T_32988_row2_col7, #T_32988_row2_col9, #T_32988_row3_col8, #T_32988_row3_col10, #T_32988_row4_col6 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_32988_row2_col6 {
#   background-color: #e2514a;
#   color: #f1f1f1;
# }
# #T_32988_row2_col10 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_32988_row3_col4, #T_32988_row6_col7 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_32988_row3_col7 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_32988_row3_col9 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_32988_row4_col4, #T_32988_row5_col9, #T_32988_row8_col8 {
#   background-color: #b61b48;
#   color: #f1f1f1;
# }
# #T_32988_row4_col7 {
#   background-color: #a90d45;
#   color: #f1f1f1;
# }
# #T_32988_row4_col8 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_32988_row4_col9 {
#   background-color: #cb334d;
#   color: #f1f1f1;
# }
# #T_32988_row4_col10, #T_32988_row6_col8 {
#   background-color: #a20643;
#   color: #f1f1f1;
# }
# #T_32988_row5_col4 {
#   background-color: #b5e1a2;
#   color: #000000;
# }
# #T_32988_row5_col7 {
#   background-color: #df4e4b;
#   color: #f1f1f1;
# }
# #T_32988_row6_col4 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_32988_row6_col6 {
#   background-color: #e1504b;
#   color: #f1f1f1;
# }
# #T_32988_row7_col4 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_32988_row7_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_32988_row8_col4 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_32988_row8_col7 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_32988_row8_col9 {
#   background-color: #af1446;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_32988">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32988_level0_col0" class="col_heading level0 col0" >HomePlanet</th>
#       <th id="T_32988_level0_col1" class="col_heading level0 col1" >CryoSleep</th>
#       <th id="T_32988_level0_col2" class="col_heading level0 col2" >Cabin</th>
#       <th id="T_32988_level0_col3" class="col_heading level0 col3" >Destination</th>
#       <th id="T_32988_level0_col4" class="col_heading level0 col4" >Age</th>
#       <th id="T_32988_level0_col5" class="col_heading level0 col5" >VIP</th>
#       <th id="T_32988_level0_col6" class="col_heading level0 col6" >RoomService</th>
#       <th id="T_32988_level0_col7" class="col_heading level0 col7" >FoodCourt</th>
#       <th id="T_32988_level0_col8" class="col_heading level0 col8" >ShoppingMall</th>
#       <th id="T_32988_level0_col9" class="col_heading level0 col9" >Spa</th>
#       <th id="T_32988_level0_col10" class="col_heading level0 col10" >VRDeck</th>
#       <th id="T_32988_level0_col11" class="col_heading level0 col11" >Name</th>
#       <th id="T_32988_level0_col12" class="col_heading level0 col12" >Transported</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >PassengerId</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32988_level0_row0" class="row_heading level0 row0" >0001_01</th>
#       <td id="T_32988_row0_col0" class="data row0 col0" >Europa</td>
#       <td id="T_32988_row0_col1" class="data row0 col1" >False</td>
#       <td id="T_32988_row0_col2" class="data row0 col2" >B/0/P</td>
#       <td id="T_32988_row0_col3" class="data row0 col3" >TRAPPIST-1e</td>
#       <td id="T_32988_row0_col4" class="data row0 col4" >39.000000</td>
#       <td id="T_32988_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_32988_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_32988_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_32988_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_32988_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_32988_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_32988_row0_col11" class="data row0 col11" >Maham Ofracculy</td>
#       <td id="T_32988_row0_col12" class="data row0 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32988_level0_row1" class="row_heading level0 row1" >0002_01</th>
#       <td id="T_32988_row1_col0" class="data row1 col0" >Earth</td>
#       <td id="T_32988_row1_col1" class="data row1 col1" >False</td>
#       <td id="T_32988_row1_col2" class="data row1 col2" >F/0/S</td>
#       <td id="T_32988_row1_col3" class="data row1 col3" >TRAPPIST-1e</td>
#       <td id="T_32988_row1_col4" class="data row1 col4" >24.000000</td>
#       <td id="T_32988_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_32988_row1_col6" class="data row1 col6" >109.000000</td>
#       <td id="T_32988_row1_col7" class="data row1 col7" >9.000000</td>
#       <td id="T_32988_row1_col8" class="data row1 col8" >25.000000</td>
#       <td id="T_32988_row1_col9" class="data row1 col9" >549.000000</td>
#       <td id="T_32988_row1_col10" class="data row1 col10" >44.000000</td>
#       <td id="T_32988_row1_col11" class="data row1 col11" >Juanna Vines</td>
#       <td id="T_32988_row1_col12" class="data row1 col12" >True</td>
#     </tr>
#     <tr>
#       <th id="T_32988_level0_row2" class="row_heading level0 row2" >0003_01</th>
#       <td id="T_32988_row2_col0" class="data row2 col0" >Europa</td>
#       <td id="T_32988_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_32988_row2_col2" class="data row2 col2" >A/0/S</td>
#       <td id="T_32988_row2_col3" class="data row2 col3" >TRAPPIST-1e</td>
#       <td id="T_32988_row2_col4" class="data row2 col4" >58.000000</td>
#       <td id="T_32988_row2_col5" class="data row2 col5" >True</td>
#       <td id="T_32988_row2_col6" class="data row2 col6" >43.000000</td>
#       <td id="T_32988_row2_col7" class="data row2 col7" >3576.000000</td>
#       <td id="T_32988_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_32988_row2_col9" class="data row2 col9" >6715.000000</td>
#       <td id="T_32988_row2_col10" class="data row2 col10" >49.000000</td>
#       <td id="T_32988_row2_col11" class="data row2 col11" >Altark Susent</td>
#       <td id="T_32988_row2_col12" class="data row2 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32988_level0_row3" class="row_heading level0 row3" >0003_02</th>
#       <td id="T_32988_row3_col0" class="data row3 col0" >Europa</td>
#       <td id="T_32988_row3_col1" class="data row3 col1" >False</td>
#       <td id="T_32988_row3_col2" class="data row3 col2" >A/0/S</td>
#       <td id="T_32988_row3_col3" class="data row3 col3" >TRAPPIST-1e</td>
#       <td id="T_32988_row3_col4" class="data row3 col4" >33.000000</td>
#       <td id="T_32988_row3_col5" class="data row3 col5" >False</td>
#       <td id="T_32988_row3_col6" class="data row3 col6" >0.000

# %% [markdown]
# #### Dropping Name
# #### Replacing Transported column's value with 0 and 1, 0 means False, 1 means True

# %%
train_dataframe.drop('Name', axis=1, inplace=True)
test_dataframe.drop('Name', axis=1, inplace=True)

train_dataframe['Transported'].replace(False, 0, inplace=True)
train_dataframe['Transported'].replace(True, 1, inplace=True)

# %% [markdown]
# #### Splitting Cabin column into 4 columns, sperated by '/' and then dropping Cabin

# %%
train_dataframe[['deck','num', 'side']] = train_dataframe['Cabin'].str.split('/', expand=True)
test_dataframe[['deck','num', 'side']] = test_dataframe['Cabin'].str.split('/', expand=True)

train_dataframe.drop('Cabin', axis=1, inplace=True)
test_dataframe.drop('Cabin', axis=1, inplace=True)

# %% [markdown]
# #### Totalling the columns "RoomService", "FoodCourt", "ShopppingMall", "Spa", and "VRDeck" and making it into 1 column, i.e., Total_Expenditure

# %%
summingColumns = ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']

train_dataframe['Total_Expenditure'] = train_dataframe[summingColumns].sum(axis=1)
test_dataframe['Total_Expenditure'] = test_dataframe[summingColumns].sum(axis=1)

# %% [markdown]
# #### Display of Train Dataframe after some preprocessing

# %%
train_dataframe.head(10).style.background_gradient(cmap="Spectral")
# Out:
# <style type="text/css">
# #T_210be_row0_col3 {
#   background-color: #eef8a4;
#   color: #000000;
# }
# #T_210be_row0_col5, #T_210be_row0_col6, #T_210be_row0_col7, #T_210be_row0_col8, #T_210be_row0_col9, #T_210be_row0_col10, #T_210be_row0_col14, #T_210be_row1_col6, #T_210be_row2_col7, #T_210be_row2_col10, #T_210be_row3_col5, #T_210be_row3_col10, #T_210be_row5_col5, #T_210be_row5_col7, #T_210be_row5_col9, #T_210be_row6_col8, #T_210be_row6_col9, #T_210be_row7_col5, #T_210be_row7_col6, #T_210be_row7_col7, #T_210be_row7_col8, #T_210be_row7_col14, #T_210be_row8_col5, #T_210be_row8_col9, #T_210be_row9_col3, #T_210be_row9_col5, #T_210be_row9_col6, #T_210be_row9_col7, #T_210be_row9_col8, #T_210be_row9_col9, #T_210be_row9_col14 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_210be_row1_col3, #T_210be_row1_col9 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_210be_row1_col5 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_210be_row1_col7 {
#   background-color: #c32a4b;
#   color: #f1f1f1;
# }
# #T_210be_row1_col8 {
#   background-color: #c9314c;
#   color: #f1f1f1;
# }
# #T_210be_row1_col10, #T_210be_row2_col3, #T_210be_row2_col6, #T_210be_row2_col8, #T_210be_row2_col14, #T_210be_row3_col7, #T_210be_row3_col9, #T_210be_row4_col5, #T_210be_row4_col10, #T_210be_row5_col10, #T_210be_row6_col10, #T_210be_row7_col10, #T_210be_row8_col10, #T_210be_row9_col10 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_210be_row1_col14 {
#   background-color: #c52c4b;
#   color: #f1f1f1;
# }
# #T_210be_row2_col5 {
#   background-color: #e2514a;
#   color: #f1f1f1;
# }
# #T_210be_row2_col9 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_210be_row3_col3, #T_210be_row6_col6 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_210be_row3_col6 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_210be_row3_col8 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_210be_row3_col14 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_210be_row4_col3, #T_210be_row5_col8, #T_210be_row8_col7 {
#   background-color: #b61b48;
#   color: #f1f1f1;
# }
# #T_210be_row4_col6 {
#   background-color: #a90d45;
#   color: #f1f1f1;
# }
# #T_210be_row4_col7 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_210be_row4_col8 {
#   background-color: #cb334d;
#   color: #f1f1f1;
# }
# #T_210be_row4_col9, #T_210be_row6_col7 {
#   background-color: #a20643;
#   color: #f1f1f1;
# }
# #T_210be_row4_col14 {
#   background-color: #d63f4f;
#   color: #f1f1f1;
# }
# #T_210be_row5_col3 {
#   background-color: #b5e1a2;
#   color: #000000;
# }
# #T_210be_row5_col6 {
#   background-color: #df4e4b;
#   color: #f1f1f1;
# }
# #T_210be_row5_col14 {
#   background-color: #c72e4c;
#   color: #f1f1f1;
# }
# #T_210be_row6_col3 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_210be_row6_col5 {
#   background-color: #e1504b;
#   color: #f1f1f1;
# }
# #T_210be_row6_col14 {
#   background-color: #e55749;
#   color: #f1f1f1;
# }
# #T_210be_row7_col3 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_210be_row7_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_210be_row8_col3 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_210be_row8_col6 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_210be_row8_col8 {
#   background-color: #af1446;
#   color: #f1f1f1;
# }
# #T_210be_row8_col14 {
#   background-color: #d43d4f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_210be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_210be_level0_col0" class="col_heading level0 col0" >HomePlanet</th>
#       <th id="T_210be_level0_col1" class="col_heading level0 col1" >CryoSleep</th>
#       <th id="T_210be_level0_col2" class="col_heading level0 col2" >Destination</th>
#       <th id="T_210be_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_210be_level0_col4" class="col_heading level0 col4" >VIP</th>
#       <th id="T_210be_level0_col5" class="col_heading level0 col5" >RoomService</th>
#       <th id="T_210be_level0_col6" class="col_heading level0 col6" >FoodCourt</th>
#       <th id="T_210be_level0_col7" class="col_heading level0 col7" >ShoppingMall</th>
#       <th id="T_210be_level0_col8" class="col_heading level0 col8" >Spa</th>
#       <th id="T_210be_level0_col9" class="col_heading level0 col9" >VRDeck</th>
#       <th id="T_210be_level0_col10" class="col_heading level0 col10" >Transported</th>
#       <th id="T_210be_level0_col11" class="col_heading level0 col11" >deck</th>
#       <th id="T_210be_level0_col12" class="col_heading level0 col12" >num</th>
#       <th id="T_210be_level0_col13" class="col_heading level0 col13" >side</th>
#       <th id="T_210be_level0_col14" class="col_heading level0 col14" >Total_Expenditure</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >PassengerId</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_210be_level0_row0" class="row_heading level0 row0" >0001_01</th>
#       <td id="T_210be_row0_col0" class="data row0 col0" >Europa</td>
#       <td id="T_210be_row0_col1" class="data row0 col1" >False</td>
#       <td id="T_210be_row0_col2" class="data row0 col2" >TRAPPIST-1e</td>
#       <td id="T_210be_row0_col3" class="data row0 col3" >39.000000</td>
#       <td id="T_210be_row0_col4" class="data row0 col4" >False</td>
#       <td id="T_210be_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_210be_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_210be_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_210be_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_210be_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_210be_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_210be_row0_col11" class="data row0 col11" >B</td>
#       <td id="T_210be_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_210be_row0_col13" class="data row0 col13" >P</td>
#       <td id="T_210be_row0_col14" class="data row0 col14" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_210be_level0_row1" class="row_heading level0 row1" >0002_01</th>
#       <td id="T_210be_row1_col0" class="data row1 col0" >Earth</td>
#       <td id="T_210be_row1_col1" class="data row1 col1" >False</td>
#       <td id="T_210be_row1_col2" class="data row1 col2" >TRAPPIST-1e</td>
#       <td id="T_210be_row1_col3" class="data row1 col3" >24.000000</td>
#       <td id="T_210be_row1_col4" class="data row1 col4" >False</td>
#       <td id="T_210be_row1_col5" class="data row1 col5" >109.000000</td>
#       <td id="T_210be_row1_col6" class="data row1 col6" >9.000000</td>
#       <td id="T_210be_row1_col7" class="data row1 col7" >25.000000</td>
#       <td id="T_210be_row1_col8" class="data row1 col8" >549.000000</td>
#       <td id="T_210be_row1_col9" class="data row1 col9" >44.000000</td>
#       <td id="T_210be_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_210be_row1_col11" class="data row1 col11" >F</td>
#       <td id="T_210be_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_210be_row1_col13" class="data row1 col13" >S</td>
#       <td id="T_210be_row1_col14" class="data row1 col14" >736.000000</td>
#     </tr>
#     <tr>
#       <th id="T_210be_level0_row2" class="row_heading level0 row2" >0003_01</th>
#       <td id="T_210be_row2_col0" class="data row2 col0" >Europa</td>
#       <td id="T_210be_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_210be_row2_col2" class="data row2 col2" >TRAPPIST-1e</td>
#       <td id="T_210be_row2_col3" class="data row2 col3" >58.000000</td>
#       <td id="T_210be_

# %% [markdown]
# #### Display of Test Dataframe after some preprocessing

# %%
test_dataframe.head(10).style.background_gradient(cmap="Spectral")
# Out:
# <style type="text/css">
# #T_bcaed_row0_col3 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_bcaed_row0_col5, #T_bcaed_row0_col6, #T_bcaed_row0_col7, #T_bcaed_row0_col8, #T_bcaed_row0_col9, #T_bcaed_row0_col13, #T_bcaed_row1_col3, #T_bcaed_row1_col5, #T_bcaed_row1_col6, #T_bcaed_row1_col7, #T_bcaed_row1_col9, #T_bcaed_row2_col5, #T_bcaed_row2_col6, #T_bcaed_row2_col7, #T_bcaed_row2_col8, #T_bcaed_row2_col9, #T_bcaed_row2_col13, #T_bcaed_row3_col5, #T_bcaed_row3_col7, #T_bcaed_row4_col6, #T_bcaed_row4_col8, #T_bcaed_row4_col9, #T_bcaed_row5_col5, #T_bcaed_row6_col5, #T_bcaed_row6_col7, #T_bcaed_row6_col8, #T_bcaed_row6_col9, #T_bcaed_row6_col13, #T_bcaed_row7_col5, #T_bcaed_row7_col6, #T_bcaed_row7_col7, #T_bcaed_row7_col8, #T_bcaed_row7_col9, #T_bcaed_row7_col13, #T_bcaed_row8_col5, #T_bcaed_row8_col6, #T_bcaed_row8_col7, #T_bcaed_row8_col8, #T_bcaed_row8_col9, #T_bcaed_row8_col13, #T_bcaed_row9_col5, #T_bcaed_row9_col7, #T_bcaed_row9_col8, #T_bcaed_row9_col9 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_bcaed_row1_col8, #T_bcaed_row3_col3, #T_bcaed_row3_col6, #T_bcaed_row3_col9, #T_bcaed_row3_col13, #T_bcaed_row4_col5, #T_bcaed_row4_col7 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_bcaed_row1_col13 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_bcaed_row2_col3, #T_bcaed_row5_col3 {
#   background-color: #d3ed9c;
#   color: #000000;
# }
# #T_bcaed_row3_col8 {
#   background-color: #c1274a;
#   color: #f1f1f1;
# }
# #T_bcaed_row4_col3, #T_bcaed_row7_col3 {
#   background-color: #ba2049;
#   color: #f1f1f1;
# }
# #T_bcaed_row4_col13, #T_bcaed_row9_col13 {
#   background-color: #cd364d;
#   color: #f1f1f1;
# }
# #T_bcaed_row5_col6 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_bcaed_row5_col7 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_bcaed_row5_col8 {
#   background-color: #b41947;
#   color: #f1f1f1;
# }
# #T_bcaed_row5_col9, #T_bcaed_row6_col3 {
#   background-color: #d63f4f;
#   color: #f1f1f1;
# }
# #T_bcaed_row5_col13 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_bcaed_row6_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_bcaed_row8_col3 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_bcaed_row9_col3 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_bcaed_row9_col6 {
#   background-color: #d23a4e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bcaed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcaed_level0_col0" class="col_heading level0 col0" >HomePlanet</th>
#       <th id="T_bcaed_level0_col1" class="col_heading level0 col1" >CryoSleep</th>
#       <th id="T_bcaed_level0_col2" class="col_heading level0 col2" >Destination</th>
#       <th id="T_bcaed_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_bcaed_level0_col4" class="col_heading level0 col4" >VIP</th>
#       <th id="T_bcaed_level0_col5" class="col_heading level0 col5" >RoomService</th>
#       <th id="T_bcaed_level0_col6" class="col_heading level0 col6" >FoodCourt</th>
#       <th id="T_bcaed_level0_col7" class="col_heading level0 col7" >ShoppingMall</th>
#       <th id="T_bcaed_level0_col8" class="col_heading level0 col8" >Spa</th>
#       <th id="T_bcaed_level0_col9" class="col_heading level0 col9" >VRDeck</th>
#       <th id="T_bcaed_level0_col10" class="col_heading level0 col10" >deck</th>
#       <th id="T_bcaed_level0_col11" class="col_heading level0 col11" >num</th>
#       <th id="T_bcaed_level0_col12" class="col_heading level0 col12" >side</th>
#       <th id="T_bcaed_level0_col13" class="col_heading level0 col13" >Total_Expenditure</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >PassengerId</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcaed_level0_row0" class="row_heading level0 row0" >0013_01</th>
#       <td id="T_bcaed_row0_col0" class="data row0 col0" >Earth</td>
#       <td id="T_bcaed_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_bcaed_row0_col2" class="data row0 col2" >TRAPPIST-1e</td>
#       <td id="T_bcaed_row0_col3" class="data row0 col3" >27.000000</td>
#       <td id="T_bcaed_row0_col4" class="data row0 col4" >False</td>
#       <td id="T_bcaed_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_bcaed_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_bcaed_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_bcaed_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_bcaed_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_bcaed_row0_col10" class="data row0 col10" >G</td>
#       <td id="T_bcaed_row0_col11" class="data row0 col11" >3</td>
#       <td id="T_bcaed_row0_col12" class="data row0 col12" >S</td>
#       <td id="T_bcaed_row0_col13" class="data row0 col13" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bcaed_level0_row1" class="row_heading level0 row1" >0018_01</th>
#       <td id="T_bcaed_row1_col0" class="data row1 col0" >Earth</td>
#       <td id="T_bcaed_row1_col1" class="data row1 col1" >False</td>
#       <td id="T_bcaed_row1_col2" class="data row1 col2" >TRAPPIST-1e</td>
#       <td id="T_bcaed_row1_col3" class="data row1 col3" >19.000000</td>
#       <td id="T_bcaed_row1_col4" class="data row1 col4" >False</td>
#       <td id="T_bcaed_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_bcaed_row1_col6" class="data row1 col6" >9.000000</td>
#       <td id="T_bcaed_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_bcaed_row1_col8" class="data row1 col8" >2823.000000</td>
#       <td id="T_bcaed_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_bcaed_row1_col10" class="data row1 col10" >F</td>
#       <td id="T_bcaed_row1_col11" class="data row1 col11" >4</td>
#       <td id="T_bcaed_row1_col12" class="data row1 col12" >S</td>
#       <td id="T_bcaed_row1_col13" class="data row1 col13" >2832.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bcaed_level0_row2" class="row_heading level0 row2" >0019_01</th>
#       <td id="T_bcaed_row2_col0" class="data row2 col0" >Europa</td>
#       <td id="T_bcaed_row2_col1" class="data row2 col1" >True</td>
#       <td id="T_bcaed_row2_col2" class="data row2 col2" >55 Cancri e</td>
#       <td id="T_bcaed_row2_col3" class="data row2 col3" >31.000000</td>
#       <td id="T_bcaed_row2_col4" class="data row2 col4" >False</td>
#       <td id="T_bcaed_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_bcaed_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_bcaed_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_bcaed_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_bcaed_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_bcaed_row2_col10" class="data row2 col10" >C</td>
#       <td id="T_bcaed_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_bcaed_row2_col12" class="data row2 col12" >S</td>
#       <td id="T_bcaed_row2_col13" class="data row2 col13" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bcaed_level0_row3" class="row_heading level0 row3" >0021_01</th>
#       <td id="T_bcaed_row3_col0" class="data row3 col0" >Europa</td>
#       <td id="T_bcaed_row3_col1" class="data row3 col1" >False</td>
#       <td id="T_bcaed_row3_col2" class="data row3 col2" >TRAPPIST-1e</td>
#       <td id="T_bcaed_row3_col3" class="data row3 col3" >38.000000</td>
#       <td id="T_bcaed_row3_col4" class="data row3 col4" >False</td>
#       <td id="T_bcaed_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_bcaed_row3_col6"

# %% [markdown]
# #### Checking the train_dataframe and test_dataframe, if they contain null and if yes then how many columns contain null

# %%
train_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8693 entries, 0001_01 to 9280_02
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   HomePlanet         8492 non-null   object
#  1   CryoSleep          8476 non-null   object
#  2   Destination        8511 non-null   object
#  3   Age                8514 non-null   float64
#  4   VIP                8490 non-null   object
#  5   RoomService        8512 non-null   float64
#  6   FoodCourt          8510 non-null   float64
#  7   ShoppingMall       8485 non-null   float64
#  8   Spa                8510 non-null   float64
#  9   VRDeck             8505 non-null   float64
#  10  Transported        8693 non-null   int64
#  11  deck               8494 non-null   object
#  12  num                8494 non-null   object
#  13  side               8494 non-null   object
#  14  Total_Expenditure  8693 non-null   float64
# dtypes: float64(7), int64(1), object(7)
# memory usage: 1.1+ MB

# %%
train_dataframe.isna().sum().to_frame().style.background_gradient(cmap="inferno")
# Out:
# <style type="text/css">
# #T_3d705_row0_col0 {
#   background-color: #f3e55d;
#   color: #000000;
# }
# #T_3d705_row1_col0 {
#   background-color: #fcffa4;
#   color: #000000;
# }
# #T_3d705_row2_col0 {
#   background-color: #fbb81d;
#   color: #000000;
# }
# #T_3d705_row3_col0 {
#   background-color: #fcb216;
#   color: #000000;
# }
# #T_3d705_row4_col0 {
#   background-color: #f2e865;
#   color: #000000;
# }
# #T_3d705_row5_col0 {
#   background-color: #fbb61a;
#   color: #000000;
# }
# #T_3d705_row6_col0, #T_3d705_row8_col0 {
#   background-color: #fbba1f;
#   color: #000000;
# }
# #T_3d705_row7_col0 {
#   background-color: #f2f27d;
#   color: #000000;
# }
# #T_3d705_row9_col0 {
#   background-color: #fac62d;
#   color: #000000;
# }
# #T_3d705_row10_col0, #T_3d705_row14_col0 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_3d705_row11_col0, #T_3d705_row12_col0, #T_3d705_row13_col0 {
#   background-color: #f4df53;
#   color: #000000;
# }
# </style>
# <table id="T_3d705">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d705_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d705_level0_row0" class="row_heading level0 row0" >HomePlanet</th>
#       <td id="T_3d705_row0_col0" class="data row0 col0" >201</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row1" class="row_heading level0 row1" >CryoSleep</th>
#       <td id="T_3d705_row1_col0" class="data row1 col0" >217</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row2" class="row_heading level0 row2" >Destination</th>
#       <td id="T_3d705_row2_col0" class="data row2 col0" >182</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_3d705_row3_col0" class="data row3 col0" >179</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row4" class="row_heading level0 row4" >VIP</th>
#       <td id="T_3d705_row4_col0" class="data row4 col0" >203</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row5" class="row_heading level0 row5" >RoomService</th>
#       <td id="T_3d705_row5_col0" class="data row5 col0" >181</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row6" class="row_heading level0 row6" >FoodCourt</th>
#       <td id="T_3d705_row6_col0" class="data row6 col0" >183</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row7" class="row_heading level0 row7" >ShoppingMall</th>
#       <td id="T_3d705_row7_col0" class="data row7 col0" >208</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row8" class="row_heading level0 row8" >Spa</th>
#       <td id="T_3d705_row8_col0" class="data row8 col0" >183</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row9" class="row_heading level0 row9" >VRDeck</th>
#       <td id="T_3d705_row9_col0" class="data row9 col0" >188</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row10" class="row_heading level0 row10" >Transported</th>
#       <td id="T_3d705_row10_col0" class="data row10 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row11" class="row_heading level0 row11" >deck</th>
#       <td id="T_3d705_row11_col0" class="data row11 col0" >199</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row12" class="row_heading level0 row12" >num</th>
#       <td id="T_3d705_row12_col0" class="data row12 col0" >199</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row13" class="row_heading level0 row13" >side</th>
#       <td id="T_3d705_row13_col0" class="data row13 col0" >199</td>
#     </tr>
#     <tr>
#       <th id="T_3d705_level0_row14" class="row_heading level0 row14" >Total_Expenditure</th>
#       <td id="T_3d705_row14_col0" class="data row14 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_dataframe.isna().sum().to_frame().style.background_gradient(cmap="inferno")
# Out:
# <style type="text/css">
# #T_7a18f_row0_col0 {
#   background-color: #fcb014;
#   color: #000000;
# }
# #T_7a18f_row1_col0, #T_7a18f_row4_col0 {
#   background-color: #f9cb35;
#   color: #000000;
# }
# #T_7a18f_row2_col0 {
#   background-color: #f9c72f;
#   color: #000000;
# }
# #T_7a18f_row3_col0 {
#   background-color: #fac228;
#   color: #000000;
# }
# #T_7a18f_row5_col0 {
#   background-color: #fb9906;
#   color: #000000;
# }
# #T_7a18f_row6_col0 {
#   background-color: #fcffa4;
#   color: #000000;
# }
# #T_7a18f_row7_col0 {
#   background-color: #f3e35a;
#   color: #000000;
# }
# #T_7a18f_row8_col0 {
#   background-color: #f1ef75;
#   color: #000000;
# }
# #T_7a18f_row9_col0 {
#   background-color: #fa9008;
#   color: #f1f1f1;
# }
# #T_7a18f_row10_col0, #T_7a18f_row11_col0, #T_7a18f_row12_col0 {
#   background-color: #f1ec6d;
#   color: #000000;
# }
# #T_7a18f_row13_col0 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7a18f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a18f_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a18f_level0_row0" class="row_heading level0 row0" >HomePlanet</th>
#       <td id="T_7a18f_row0_col0" class="data row0 col0" >87</td>
#     </tr>
#     <tr>
#       <th id="T_7a18f_level0_row1" class="row_heading level0 row1" >CryoSleep</th>
#       <td id="T_7a18f_row1_col0" class="data row1 col0" >93</td>
#     </tr>
#     <tr>
#       <th id="T_7a18f_level0_row2" class="row_heading level0 row2" >Destination</th>
#       <td id="T_7a18f_row2_col0" class="data row2 col0" >92</td>
#     </tr>
#     <tr>
#       <th id="T_7a18f_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_7a18f_row3_col0" class="data row3 col0" >91</td>
#     </tr>
#     <tr>
#       <th id="T_7a18f_level0_row4" class="row_heading level0 row4" >VIP</th>
#       <td id="T_7a18f_row4_col0" class="data row4 col0" >93</td>
#     </tr>
#     <tr>
#       <th id="T_7a18f_level0_row5" class="row_heading level0 row5" >RoomService</th>
#       <td id="T_7a18f_row5_col0" class="data row5 col0" >82</td>
#     </tr>
#     <tr>
#       <th id="T_7a18f_level0_row6" class="row_heading level0 row6" >FoodCourt</th>
#       <td id="T_7a18f_row6_col0" class="data row6 col0" >106</td>
#     </tr>
#     <tr>
#       <th id="T_7a18f_level0_row7" class="row_heading level0 row7" >ShoppingMall</th>
#       <td id="T_7a18f_row7_col0" class="data row7 col0" >98</td>
#     </tr>
#     <tr>
#       <th id="T_7a18f_level0_row8" class="row_heading level0 row8" >Spa</th>
#       <td id="T_7a18f_row8_col0" class="data row8 col0" >101</td>
#     </tr>
#     <tr>
#       <th id="T_7a18f_level0_row9" class="row_heading level0 row9" >VRDeck</th>
#       <td id="T_7a18f_row9_col0" class="data row9 col0" >80</td>
#     </tr>
#     <tr>
#       <th id="T_7a18f_level0_row10" class="row_heading level0 row10" >deck</th>
#       <td id="T_7a18f_row10_col0" class="data row10 col0" >100</td>
#     </tr>
#     <tr>
#       <th id="T_7a18f_level0_row11" class="row_heading level0 row11" >num</th>
#       <td id="T_7a18f_row11_col0" class="data row11 col0" >100</td>
#     </tr>
#     <tr>
#       <th id="T_7a18f_level0_row12" class="row_heading level0 row12" >side</th>
#       <td id="T_7a18f_row12_col0" class="data row12 col0" >100</td>
#     </tr>
#     <tr>
#       <th id="T_7a18f_level0_row13" class="row_heading level0 row13" >Total_Expenditure</th>
#       <td id="T_7a18f_row13_col0" class="data row13 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
nullColumns = train_dataframe.isnull().sum().sort_values(ascending=False)
nullColumns = list(nullColumns[nullColumns>1].index)
nullColumns
# Out:
# ['CryoSleep',
#  'ShoppingMall',
#  'VIP',
#  'HomePlanet',
#  'deck',
#  'num',
#  'side',
#  'VRDeck',
#  'FoodCourt',
#  'Spa',
#  'Destination',
#  'RoomService',
#  'Age']

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Converting object type data columns into category type

# %%
object_cols = [col for col in train_dataframe.columns if train_dataframe[col].dtype == 'object' or train_dataframe[col].dtype == 'category']
numeric_cols = [col for col in train_dataframe.columns if train_dataframe[col].dtype == 'float64']
print(f'Numeric data type Columns: {numeric_cols}')
print(f'Object data type columns: {object_cols}')
train_dataframe[object_cols] = train_dataframe[object_cols].astype('category')
test_dataframe[object_cols] = test_dataframe[object_cols].astype('category')
# Out:
# Numeric data type Columns -- ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck', 'Total_Expenditure']
# Object data type columns -- ['HomePlanet', 'CryoSleep', 'Destination', 'VIP', 'deck', 'num', 'side']

# %% [markdown]
# #### Float or numeric values are encoded (converted) from categorical values in objects or strings for use in classification.

# %% [markdown]
# ## Many kaggle competition suggested to use this method with for better accuracy

# %%
ordinalEncoder = OrdinalEncoder()

encode_df = pd.concat([train_dataframe, test_dataframe])
encode_df[object_cols] = encode_df[object_cols].astype('category')
encode_df[object_cols] = ordinalEncoder.fit_transform(encode_df[object_cols])

del train_dataframe, test_dataframe

train_dataframe = encode_df.iloc[:8693, :]
test_dataframe = encode_df.iloc[8693: , :]

del encode_df

# %% [markdown]
# #### Removing Transported column from Test Dataframe

# %%
test_dataframe.drop('Transported', inplace=True, axis=1)

# %% [markdown]
# ### Dataframe after Transported Dropped

# %%
test_dataframe.head(10).style.background_gradient(cmap="Spectral")
# Out:
# <style type="text/css">
# #T_f217d_row0_col0, #T_f217d_row0_col4, #T_f217d_row0_col5, #T_f217d_row0_col6, #T_f217d_row0_col7, #T_f217d_row0_col8, #T_f217d_row0_col9, #T_f217d_row0_col13, #T_f217d_row1_col0, #T_f217d_row1_col1, #T_f217d_row1_col3, #T_f217d_row1_col4, #T_f217d_row1_col5, #T_f217d_row1_col6, #T_f217d_row1_col7, #T_f217d_row1_col9, #T_f217d_row2_col2, #T_f217d_row2_col4, #T_f217d_row2_col5, #T_f217d_row2_col6, #T_f217d_row2_col7, #T_f217d_row2_col8, #T_f217d_row2_col9, #T_f217d_row2_col11, #T_f217d_row2_col13, #T_f217d_row3_col1, #T_f217d_row3_col4, #T_f217d_row3_col5, #T_f217d_row3_col7, #T_f217d_row3_col11, #T_f217d_row4_col0, #T_f217d_row4_col1, #T_f217d_row4_col4, #T_f217d_row4_col6, #T_f217d_row4_col8, #T_f217d_row4_col9, #T_f217d_row5_col0, #T_f217d_row5_col1, #T_f217d_row5_col4, #T_f217d_row5_col5, #T_f217d_row5_col12, #T_f217d_row6_col2, #T_f217d_row6_col4, #T_f217d_row6_col5, #T_f217d_row6_col7, #T_f217d_row6_col8, #T_f217d_row6_col9, #T_f217d_row6_col10, #T_f217d_row6_col12, #T_f217d_row6_col13, #T_f217d_row7_col4, #T_f217d_row7_col5, #T_f217d_row7_col6, #T_f217d_row7_col7, #T_f217d_row7_col8, #T_f217d_row7_col9, #T_f217d_row7_col11, #T_f217d_row7_col13, #T_f217d_row8_col2, #T_f217d_row8_col4, #T_f217d_row8_col5, #T_f217d_row8_col6, #T_f217d_row8_col7, #T_f217d_row8_col8, #T_f217d_row8_col9, #T_f217d_row8_col11, #T_f217d_row8_col13, #T_f217d_row9_col0, #T_f217d_row9_col1, #T_f217d_row9_col2, #T_f217d_row9_col4, #T_f217d_row9_col5, #T_f217d_row9_col7, #T_f217d_row9_col8, #T_f217d_row9_col9 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_f217d_row0_col1, #T_f217d_row0_col2, #T_f217d_row0_col10, #T_f217d_row0_col12, #T_f217d_row1_col2, #T_f217d_row1_col8, #T_f217d_row1_col12, #T_f217d_row2_col0, #T_f217d_row2_col1, #T_f217d_row2_col12, #T_f217d_row3_col0, #T_f217d_row3_col2, #T_f217d_row3_col3, #T_f217d_row3_col6, #T_f217d_row3_col9, #T_f217d_row3_col12, #T_f217d_row3_col13, #T_f217d_row4_col2, #T_f217d_row4_col5, #T_f217d_row4_col7, #T_f217d_row4_col12, #T_f217d_row5_col2, #T_f217d_row5_col11, #T_f217d_row6_col0, #T_f217d_row6_col1, #T_f217d_row7_col0, #T_f217d_row7_col1, #T_f217d_row7_col2, #T_f217d_row7_col12, #T_f217d_row8_col0, #T_f217d_row8_col1, #T_f217d_row8_col12, #T_f217d_row9_col11, #T_f217d_row9_col12 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_f217d_row0_col3 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_f217d_row0_col11 {
#   background-color: #9fd8a4;
#   color: #000000;
# }
# #T_f217d_row1_col10, #T_f217d_row4_col10, #T_f217d_row5_col10, #T_f217d_row9_col10 {
#   background-color: #66c2a5;
#   color: #000000;
# }
# #T_f217d_row1_col11 {
#   background-color: #6ec5a5;
#   color: #000000;
# }
# #T_f217d_row1_col13 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_f217d_row2_col3, #T_f217d_row5_col3 {
#   background-color: #d3ed9c;
#   color: #000000;
# }
# #T_f217d_row2_col10, #T_f217d_row3_col10 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_f217d_row3_col8 {
#   background-color: #c1274a;
#   color: #f1f1f1;
# }
# #T_f217d_row4_col3, #T_f217d_row7_col3 {
#   background-color: #ba2049;
#   color: #f1f1f1;
# }
# #T_f217d_row4_col11 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_f217d_row4_col13, #T_f217d_row9_col13 {
#   background-color: #cd364d;
#   color: #f1f1f1;
# }
# #T_f217d_row5_col6 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_f217d_row5_col7 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_f217d_row5_col8 {
#   background-color: #b41947;
#   color: #f1f1f1;
# }
# #T_f217d_row5_col9, #T_f217d_row6_col3 {
#   background-color: #d63f4f;
#   color: #f1f1f1;
# }
# #T_f217d_row5_col13 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_f217d_row6_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f217d_row6_col11 {
#   background-color: #cdeb9d;
#   color: #000000;
# }
# #T_f217d_row7_col10, #T_f217d_row8_col10 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_f217d_row8_col3 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_f217d_row9_col3 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_f217d_row9_col6 {
#   background-color: #d23a4e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f217d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f217d_level0_col0" class="col_heading level0 col0" >HomePlanet</th>
#       <th id="T_f217d_level0_col1" class="col_heading level0 col1" >CryoSleep</th>
#       <th id="T_f217d_level0_col2" class="col_heading level0 col2" >Destination</th>
#       <th id="T_f217d_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_f217d_level0_col4" class="col_heading level0 col4" >VIP</th>
#       <th id="T_f217d_level0_col5" class="col_heading level0 col5" >RoomService</th>
#       <th id="T_f217d_level0_col6" class="col_heading level0 col6" >FoodCourt</th>
#       <th id="T_f217d_level0_col7" class="col_heading level0 col7" >ShoppingMall</th>
#       <th id="T_f217d_level0_col8" class="col_heading level0 col8" >Spa</th>
#       <th id="T_f217d_level0_col9" class="col_heading level0 col9" >VRDeck</th>
#       <th id="T_f217d_level0_col10" class="col_heading level0 col10" >deck</th>
#       <th id="T_f217d_level0_col11" class="col_heading level0 col11" >num</th>
#       <th id="T_f217d_level0_col12" class="col_heading level0 col12" >side</th>
#       <th id="T_f217d_level0_col13" class="col_heading level0 col13" >Total_Expenditure</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >PassengerId</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f217d_level0_row0" class="row_heading level0 row0" >0013_01</th>
#       <td id="T_f217d_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_f217d_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_f217d_row0_col2" class="data row0 col2" >2.000000</td>
#       <td id="T_f217d_row0_col3" class="data row0 col3" >27.000000</td>
#       <td id="T_f217d_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_f217d_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_f217d_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_f217d_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_f217d_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_f217d_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_f217d_row0_col10" class="data row0 col10" >6.000000</td>
#       <td id="T_f217d_row0_col11" class="data row0 col11" >1117.000000</td>
#       <td id="T_f217d_row0_col12" class="data row0 col12" >1.000000</td>
#       <td id="T_f217d_row0_col13" class="data row0 col13" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f217d_level0_row1" class="row_heading level0 row1" >0018_01</th>
#       <td id="T_f217d_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_f217d_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_f217d_row1_col2" class="data row1 col2" >2.000000</td>
#       <td id="T_f217d_row1_col3" class="data row1 col3" >19.000000</td>
#       <td id="T_f217d_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_f217d_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_f217d_row1_col6" class="data row1 col6" >9.000000</td>
#       <td id="T_f217d_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_f217d_row1_col8" class="data row1 col8" >2823.000000</td>
#       <td id="T_f217d_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_f217d_row1_col10" class="data row1 col10" >5.000000</td>
#       <td id="T

# %% [markdown]
# #### Missing columns are being replaced by the mean of that column

# %%
colTransformer = ColumnTransformer([("imp", SimpleImputer(strategy='mean'), nullColumns)])
train_dataframe[nullColumns] = colTransformer.fit_transform(train_dataframe[nullColumns])
test_dataframe[nullColumns] = colTransformer.fit_transform(test_dataframe[nullColumns])

# %% [markdown]
# ## Training the models

# %% [markdown]
# #### Splitting the test and train in 70:30 respectively for training the model

# %%
X = train_dataframe.copy()
y = X.pop('Transported')
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=40)

# %% [markdown]
# #### Implementing Catboost, unlike other models, it can't be imported btu can only be installed first

# %% [markdown]
# ### To choose the best model, we purposely compare 4 models. then put to use in the last stage.
# 1. RandomForestClassifier
# 2. AdaBoostClassifier
# 3. XGBClassifier
# 4. CatBoostClassifier

# %% [markdown]
# #### Correctness score and cross validation, two metrics that measure the model's accuracy, will be used to assess the model's accuracy. We define cross validation and verbose using GridSearchCV.

# %%
# model_list= {}
def predict_and_acc(model, verbose=None):
    
    if verbose == None:
        model = model()
        model.fit(X_train, y_train)
        predict = model.predict(X_test)
        cvs = cross_val_score(model, X, y, cv=4)
        print(f'The accuracy score of {str(model)} is {float(accuracy_score(y_test, predict))}')
        print(f'The cross validation of {str(model)} is:{cvs} with mean of {cvs.mean()}')
    else:
        model = model(verbose=verbose)
        model.fit(X_train, y_train)
        predict = model.predict(X_test)
        cvs = cross_val_score(model, X, y, cv=4)
        print(f'The accuracy score of {str(model)} is {float(accuracy_score(y_test, predict))}')
        print(f'The cross validation of {str(model)} is:{cvs} with mean of {cvs.mean()}')

# %%
predict_and_acc(RandomForestClassifier, None)

# %%
predict_and_acc(AdaBoostClassifier)

# %%
predict_and_acc(XGBClassifier)

# %%
predict_and_acc(CatBoostClassifier, verbose=False)

# %%
model_fs = CatBoostClassifier(verbose=False)
sf = SequentialFeatureSelector(model_fs, scoring='accuracy', direction = 'backward')
sf.fit(X,y)
# Out:
# d:\ProgramData\Anaconda3\envs\SpaceTitanic\lib\site-packages\sklearn\feature_selection\_sequential.py:188: FutureWarning: Leaving `n_features_to_select` to None is deprecated in 1.0 and will become 'auto' in 1.3. To keep the same behaviour as with None (i.e. select half of the features) and avoid this warning, you should manually set `n_features_to_select='auto'` and set tol=None when creating an instance.
#   warnings.warn(
# SequentialFeatureSelector(direction='backward',
#                           estimator=<catboost.core.CatBoostClassifier object at 0x000002AC97AFA6B0>,
#                           scoring='accuracy')

# %%
best_features = list(sf.get_feature_names_out())
best_features
# Out:
# ['CryoSleep', 'RoomService', 'Spa', 'VRDeck', 'deck', 'side', 'SumSpends']

# %%
model = CatBoostClassifier(verbose=False, eval_metric='Accuracy')
model.fit(X[best_features], y)
prediction = model.predict(test_dataframe[best_features])
# Out:
# d:\ProgramData\Anaconda3\envs\SpaceTitanic\lib\site-packages\catboost\core.py:1411: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# d:\ProgramData\Anaconda3\envs\SpaceTitanic\lib\site-packages\catboost\core.py:1411: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,

# %% [markdown]
# ## Predictions

# %%
final = pd.DataFrame()
final.index = test_dataframe.index
final['Transported'] = prediction
final['Transported'].replace(0, False, inplace=True)
final['Transported'].replace(1, True, inplace=True)
final.head(10)
# Out:
#              Transported
# PassengerId
# 0013_01             True
# 0018_01            False
# 0019_01             True
# 0021_01             True
# 0023_01             True
# 0027_01             True
# 0029_01             True
# 0032_01             True
# 0032_02             True
# 0033_01             True

# %%
final.to_csv('submission.csv')
